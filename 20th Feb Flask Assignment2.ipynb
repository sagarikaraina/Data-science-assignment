# %% [markdown]
# ## Q1. Explain GET and POST methods.

# %% [markdown]
# * The GET method is a HTTP method used to retrieve data from a server.
# * a GET request is handled using the @app.route decorator.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/users', methods=['GET'])
def get_users():
    # retrieve and return list of users
    pass

# %% [markdown]
# * The POST method is used to send data to a server to create or update a resource.
# * POST request is handled using the @app.route decorator with methods=['POST'].

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/users', methods=['POST'])
def create_user():
    data = request.json
    # create new user based on data
    pass

# %% [markdown]
# ## Q2. Why is request used in Flask?

# %% [markdown]
# * The request object in Flask is used to handle incoming HTTP requests to the Flask application.
# * It provides access to the data that was sent with the request such as form data, query parameters, and JSON data.

# %% [markdown]
# ## Q3. Why is redirect() used in Flask?

# %% [markdown]
# * The redirect() function in Flask is used to redirect the user to a different URL.
# * It is typically used to redirect the user after a form submission or to redirect the user to a login page if they are not authenticated.

# %%
from flask import Flask, redirect, url_for, request

app = Flask(__name__)

@app.route('/submit_form', methods=['POST'])
def submit_form():
    # process form data
    return redirect(url_for('success'))

@app.route('/success')
def success():
    return "Form submitted successfully!"

# %% [markdown]
# ## Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# * Templates in Flask are used to separate the presentation logic from the business logic of a web application.
# * The render_template() function in Flask is used to render a template with dynamic data. It takes the name of the template file as its first argument and any data to be passed to the template as keyword arguments. The function returns the rendered HTML code.

# %% [markdown]
# ## Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:68b28447-ef58-4779-9e86-352621fecd93.png)

# %% [markdown]
# ![image.png](attachment:ae9d3cd7-158c-4476-a7eb-edaca170a6c1.png)
